# %%
# Uncomment below to install pandas into virtual environment
#%pip install pandas

import pandas as pd

# %%
hr_data = pd.read_csv('HumanResources.csv')

# %%
hr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13624 entries, 0 to 13623
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   employee_id         13624 non-null  object
#  1   first_name          13624 non-null  object
#  2   last_name           13624 non-null  object
#  3   gender              13624 non-null  object
#  4   state               13624 non-null  object
#  5   city                13624 non-null  object
#  6   hire_date           13624 non-null  object
#  7   department          13624 non-null  object
#  8   job_title           13624 non-null  object
#  9   education_level     13624 non-null  object
#  10  salary              13624 non-null  int64
#  11  performance_rating  13624 non-null  object
#  12  overtime            13624 non-null  object
#  13  birth_date          13624 non-null  object
#  14  termination_date    1521 non-null   object
# dtypes: int64(1), object(14)
# ...

# %%
hr_data
# Out:
#        employee_id first_name  last_name  gender           state  \
# 0      00-95822412       Mark    Johnson    Male        New York
# 1      00-42868828     Daniel      Doyle    Male        New York
# 2      00-83197857  Stephanie     Miller  Female        Illinois
# 3      00-13999315     Amanda   Robinson  Female        New York
# 4      00-90801586     Alyssa   Gonzalez  Female        New York
# ...            ...        ...        ...     ...             ...
# 13619  00-80843394     Justin     Dorsey    Male        New York
# 13620  00-33855022    Melanie      Banks  Female        New York
# 13621  00-52240254      Tommy     Wright    Male  North Carolina
# 13622  00-20650875      Traci  Carpenter  Female        Illinois
# 13623  00-32381788      Julie      Smith  Female       Wisconsin
#
#                 city   hire_date  department              job_title  \
# 0      New York City  2016-04-10       Sales       Sales Consultant
# ...

# %%
hr_data.to_excel('HumanResources.xlsx', sheet_name='HR_Data')
